# %% [markdown]
# ### 성적 예측

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.DataFrame([[2,20],[4,40],[6,60],[9,90]],
                   index=["해도","병관","은비","수현"],
                   columns=["시간","성적"])
data
# Out:
#     시간  성적
# 해도   2  20
# 병관   4  40
# 은비   6  60
# 수현   9  90

# %% [markdown]
# #### 수학공식을 이용한 모델

# %%
from sklearn.linear_model import LinearRegression

linear = LinearRegression()

linear.fit(data[["시간"]],data["성적"])
# Out:
# LinearRegression()

# %%
# R2 score= 1-mse/표준편차
linear.score(data[["시간"]],data["성적"])
# Out:
# 1.0

# %%
# w, b를 출력
print("w : ",linear.coef_)
print("b : ",linear.intercept_)
# Out:
# w :  [10.]
# b :  -7.105427357601002e-15

# %%
linear.predict([[7]])
# Out:
# array([70.])

# %% [markdown]
# ### 경사하강법을 이용해서 회귀분석

# %%
# 경사하강법 : 모든데이터에 대해서 기울기를 계산 : 너무 느림
# 확률적 경사하강법 : 일부 데이터만 샘플링 해서 기울기를 계산
from sklearn.linear_model import SGDRegressor

# max_iter : 몇번 반복할 것인지
# eta : 학습률
sgd = SGDRegressor(max_iter=5000,
                   eta0=0.01, verbose=1)
sgd.fit(data[["시간"]],data["성적"])
# Out:
# -- Epoch 1
# Norm: 7.99, NNZs: 1, Bias: 1.170238, T: 4, Avg. loss: 936.617207
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 9.24, NNZs: 1, Bias: 1.326765, T: 8, Avg. loss: 39.183222
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 9.58, NNZs: 1, Bias: 1.372006, T: 12, Avg. loss: 3.897111
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 9.71, NNZs: 1, Bias: 1.387213, T: 16, Avg. loss: 0.757318
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 9.75, NNZs: 1, Bias: 1.388397, T: 20, Avg. loss: 0.313747
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 9.77, NNZs: 1, Bias: 1.384965, T: 24, Avg. loss: 0.232564
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 9.78, NNZs: 1, Bias: 1.382012, T: 28, Avg. loss: 0.220027
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 9.79, NNZs: 1, Bias: 1.379177, T: 32, Avg. loss: 0.206198
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 9.79, NNZs: 1, Bias: 1.374503, T: 36, Avg. loss: 0.203742
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 9.79, NNZs: 1, Bias: 1.369281, T: 40, Avg. loss: 0.197543
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 9.79, NNZs: 1, Bias: 1.365460, T: 44, Avg. loss: 0.201893
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 9.80, NNZs: 1, Bias: 1.362300, T: 48, Avg. loss: 0.197261
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 9.80, NNZs: 1, Bias: 1.357921, T: 52, Avg. loss: 0.196568
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 9.79, NNZs: 1, Bias: 1.353139, T: 56, Avg. loss: 0.191532
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 9.79, NNZs: 1, Bias: 1.349552, T: 60, Avg. loss: 0.195121
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 9.80, NNZs: 1, Bias: 1.346574, T: 64, Avg. loss: 0.191549
# Total training time: 0.00 seconds.
# -- Epoch 17
# Norm: 9.80, NNZs: 1, Bias: 1.342564, T: 68, Avg. loss: 0.190983
# Total training time: 0.00 seconds.
# -- Epoch 18
# Norm: 9.79, NNZs: 1, Bias: 1.338172, T: 72, Avg. loss: 0.186657
# Total training time: 0.00 seconds.
# -- Epoch 19
# Norm: 9.80, NNZs: 1, Bias: 1.334807, T: 76, Avg. loss: 0.189674
# Total training time: 0.00 seconds.
# -- Epoch 20
# Norm: 9.80, NNZs: 1, Bias: 1.331992, T: 80, Avg. loss: 0.186638
# Total training time: 0.00 seconds.
# -- Epoch 21
# Norm: 9.80, NNZs: 1, Bias: 1.328265, T: 84, Avg. loss: 0.186119
# Total training time: 0.00 seconds.
# -- Epoch 22
# Norm: 9.80, NNZs: 1, Bias: 1.324171, T: 88, Avg. loss: 0.182294
# Total training time: 0.00 seconds.
# -- Epoch 23
# Norm: 9.80, NNZs: 1, Bias: 1.320986, T: 92, Avg. loss: 0.184901
# Total training time: 0.00 seconds.
# -- Epoch 24
# Norm: 9.80, NNZs: 1, Bias: 1.318304, T: 96, Avg. loss: 0.182231
# Total training time: 0.00 seconds.
# -- Epoch 25
# Norm: 9.80, NNZs: 1, Bias: 1.314798, T: 100, Avg. loss: 0.181743
# Total training time: 0.00 seconds.
# -- Epoch 26
# Norm: 9.80, NNZs: 1, Bias: 1.310942, T: 104, Avg. loss: 0.178293
# Total training time: 0.00 seconds.
# -- Epoch 27
# Norm: 9.80, NNZs: 1, Bias: 1.307905, T: 108, Avg. loss: 0.180592
# Total training time: 0.00 seconds.
# -- Epoch 28
# Norm: 9.80, NNZs: 1, Bias: 1.305333, T: 112, Avg. loss: 0.178194
# Total training time: 0.00 seconds.
# -- Epoch 29
# Norm: 9.80, NNZs: 1, Bias: 1.302008, T: 116, Avg. loss: 0.177730
# Total training time: 0.00 seconds.
# -- Epoch 30
# Norm: 9.80, NNZs: 1, Bias: 1.298347, T: 120, Avg. loss: 0.174575
# Total training time: 0.00 seconds.
# -- Epoch 31
# Norm: 9.80, NNZs: 1, Bias: 1.295435, T: 124, Avg. loss: 0.176633
# Total training time: 0.00 seconds.
# -- Epoch 32
# Norm: 9.81, NNZs: 1, Bias: 1.292959, T: 128, Avg. loss: 0.174447
# Total training time: 0.00 seconds.
# -- Epoch 33
# Norm: 9.81, NNZs: 1, Bias: 1.289784, T: 132, Avg. loss: 0.174004
# Total training time: 0.00 seconds.
# -- Epoch 34
# Norm: 9.80, NNZs: 1, Bias: 1.286289, T: 136, Avg. loss: 0.171089
# Total training time: 0.00 seconds.
# -- Epoch 35
# Norm: 9.80, NNZs: 1, Bias: 1.283486, T: 140, Avg. loss: 0.172951
# Total training time: 0.00 seconds.
# -- Epoch 36
# Norm: 9.81, NNZs: 1, Bias: 1.281092, T: 144, Avg. loss: 0.170938
# Total training time: 0.00 seconds.
# -- Epoch 37
# Norm: 9.81, NNZs: 1, Bias: 1.278047, T: 148, Avg. loss: 0.170512
# Total training time: 0.00 seconds.
# -- Epoch 38
# Norm: 9.80, NNZs: 1, Bias: 1.274695, T: 152, Avg. loss: 0.167797
# Total training time: 0.00 seconds.
# -- Epoch 39
# Norm: 9.81, NNZs: 1, Bias: 1.271987, T: 156, Avg. loss: 0.169497
# Total training time: 0.00 seconds.
# -- Epoch 40
# Norm: 9.81, NNZs: 1, Bias: 1.269667, T: 160, Avg. loss: 0.167627
# Total training time: 0.00 seconds.
# -- Epoch 41
# Norm: 9.81, NNZs: 1, Bias: 1.266736, T: 164, Avg. loss: 0.167216
# Total training time: 0.00 seconds.
# -- Epoch 42
# Norm: 9.81, NNZs: 1, Bias: 1.263509, T: 168, Avg. loss: 0.164673
# Total training time: 0.00 seconds.
# -- Epoch 43
# Norm: 9.81, NNZs: 1, Bias: 1.260887, T: 172, Avg. loss: 0.166236
# Total training time: 0.00 seconds.
# -- Epoch 44
# Norm: 9.81, NNZs: 1, Bias: 1.258632, T: 176, Avg. loss: 0.164488
# Total training time: 0.00 seconds.
# -- Epoch 45
# Norm: 9.81, NNZs: 1, Bias: 1.255801, T: 180, Avg. loss: 0.164091
# Total training time: 0.00 seconds.
# -- Epoch 46
# Norm: 9.81, NNZs: 1, Bias: 1.252686, T: 184, Avg. loss: 0.161695
# Total training time: 0.00 seconds.
# -- Epoch 47
# Norm: 9.81, NNZs: 1, Bias: 1.250141, T: 188, Avg. loss: 0.163141
# Total training time: 0.00 seconds.
# -- Epoch 48
# Norm: 9.81, NNZs: 1, Bias: 1.247946, T: 192, Avg. loss: 0.161498
# Total training time: 0.00 seconds.
# -- Epoch 49
# Norm: 9.81, NNZs: 1, Bias: 1.245206, T: 196, Avg. loss: 0.161113
# Total training time: 0.00 seconds.
# -- Epoch 50
# Norm: 9.81, NNZs: 1, Bias: 1.242190, T: 200, Avg. loss: 0.158847
# Total training time: 0.00 seconds.
# -- Epoch 51
# Norm: 9.81, NNZs: 1, Bias: 1.239715, T: 204, Avg. loss: 0.160191
# Total training time: 0.00 seconds.
# -- Epoch 52
# Norm: 9.81, NNZs: 1, Bias: 1.237576, T: 208, Avg. loss: 0.158640
# Total training time: 0.00 seconds.
# -- Epoch 53
# Norm: 9.81, NNZs: 1, Bias: 1.234917, T: 212, Avg. loss: 0.158266
# Total training time: 0.00 seconds.
# -- Epoch 54
# Norm: 9.81, NNZs: 1, Bias: 1.231992, T: 216, Avg. loss: 0.156115
# Total training time: 0.00 seconds.
# -- Epoch 55
# Norm: 9.81, NNZs: 1, Bias: 1.229582, T: 220, Avg. loss: 0.157371
# Total training time: 0.00 seconds.
# -- Epoch 56
# Norm: 9.82, NNZs: 1, Bias: 1.227493, T: 224, Avg. loss: 0.155900
# Total training time: 0.00 seconds.
# -- Epoch 57
# Norm: 9.81, NNZs: 1, Bias: 1.224908, T: 228, Avg. loss: 0.155537
# Total training time: 0.00 seconds.
# -- Epoch 58
# Norm: 9.81, NNZs: 1, Bias: 1.222067, T: 232, Avg. loss: 0.153489
# Total training time: 0.00 seconds.
# -- Epoch 59
# Norm: 9.81, NNZs: 1, Bias: 1.219716, T: 236, Avg. loss: 0.154666
# Total training time: 0.00 seconds.
# -- Epoch 60
# Norm: 9.82, NNZs: 1, Bias: 1.217673, T: 240, Avg. loss: 0.153267
# Total training time: 0.00 seconds.
# -- Epoch 61
# Norm: 9.82, NNZs: 1, Bias: 1.215158, T: 244, Avg. loss: 0.152914
# Total training time: 0.00 seconds.
# -- Epoch 62
# Norm: 9.81, NNZs: 1, Bias: 1.212392, T: 248, Avg. loss: 0.150958
# Total training time: 0.00 seconds.
# -- Epoch 63
# Norm: 9.82, NNZs: 1, Bias: 1.210096, T: 252, Avg. loss: 0.152065
# Total training time: 0.00 seconds.
# -- Epoch 64
# Norm: 9.82, NNZs: 1, Bias: 1.208098, T: 256, Avg. loss: 0.150731
# Total training time: 0.00 seconds.
# -- Epoch 65
# Norm: 9.82, NNZs: 1, Bias: 1.205645, T: 260, Avg. loss: 0.150387
# Total training time: 0.00 seconds.
# -- Epoch 66
# Norm: 9.82, NNZs: 1, Bias: 1.202951, T: 264, Avg. loss: 0.148516
# Total training time: 0.00 seconds.
# -- Epoch 67
# Norm: 9.82, NNZs: 1, Bias: 1.200706, T: 268, Avg. loss: 0.149560
# Total training time: 0.00 seconds.
# -- Epoch 68
# Norm: 9.82, NNZs: 1, Bias: 1.198748, T: 272, Avg. loss: 0.148285
# Total training time: 0.00 seconds.
# -- Epoch 69
# Norm: 9.82, NNZs: 1, Bias: 1.196355, T: 276, Avg. loss: 0.147949
# Total training time: 0.00 seconds.
# -- Epoch 70
# Norm: 9.82, NNZs: 1, Bias: 1.193726, T: 280, Avg. loss: 0.146155
# Total training time: 0.00 seconds.
# -- Epoch 71
# Norm: 9.82, NNZs: 1, Bias: 1.191529, T: 284, Avg. loss: 0.147142
# Total training time: 0.00 seconds.
# -- Epoch 72
# Norm: 9.82, NNZs: 1, Bias: 1.189610, T: 288, Avg. loss: 0.145921
# Total training time: 0.00 seconds.
# -- Epoch 73
# Norm: 9.82, NNZs: 1, Bias: 1.187271, T: 292, Avg. loss: 0.145593
# Total training time: 0.00 seconds.
# -- Epoch 74
# Norm: 9.82, NNZs: 1, Bias: 1.184704, T: 296, Avg. loss: 0.143870
# Total training time: 0.00 seconds.
# -- Epoch 75
# Norm: 9.82, NNZs: 1, Bias: 1.182552, T: 300, Avg. loss: 0.144804
# Total training time: 0.00 seconds.
# -- Epoch 76
# Norm: 9.82, NNZs: 1, Bias: 1.180670, T: 304, Avg. loss: 0.143632
# Total training time: 0.00 seconds.
# -- Epoch 77
# Norm: 9.82, NNZs: 1, Bias: 1.178382, T: 308, Avg. loss: 0.143312
# Total training time: 0.00 seconds.
# -- Epoch 78
# Norm: 9.82, NNZs: 1, Bias: 1.175872, T: 312, Avg. loss: 0.141654
# Total training time: 0.00 seconds.
# -- Epoch 79
# Norm: 9.82, NNZs: 1, Bias: 1.173763, T: 316, Avg. loss: 0.142542
# Total training time: 0.00 seconds.
# -- Epoch 80
# Norm: 9.82, NNZs: 1, Bias: 1.171915, T: 320, Avg. loss: 0.141415
# Total training time: 0.00 seconds.
# -- Epoch 81
# Norm: 9.82, NNZs: 1, Bias: 1.169675, T: 324, Avg. loss: 0.141102
# Total training time: 0.00 seconds.
# -- Epoch 82
# Norm: 9.82, NNZs: 1, Bias: 1.167219, T: 328, Avg. loss: 0.139505
# Total training time: 0.00 seconds.
# -- Epoch 83
# Norm: 9.82, NNZs: 1, Bias: 1.165151, T: 332, Avg. loss: 0.140349
# Total training time: 0.00 seconds.
# -- Epoch 84
# Norm: 9.82, NNZs: 1, Bias: 1.163336, T: 336, Avg. loss: 0.139264
# Total training time: 0.00 seconds.
# -- Epoch 85
# Norm: 9.82, NNZs: 1, Bias: 1.161142, T: 340, Avg. loss: 0.138958
# Total training time: 0.00 seconds.
# -- Epoch 86
# Norm: 9.82, NNZs: 1, Bias: 1.158737, T: 344, Avg. loss: 0.137417
# Total training time: 0.00 seconds.
# -- Epoch 87
# Norm: 9.82, NNZs: 1, Bias: 1.156706, T: 348, Avg. loss: 0.138222
# Total training time: 0.00 seconds.
# -- Epoch 88
# Norm: 9.83, NNZs: 1, Bias: 1.154922, T: 352, Avg. loss: 0.137176
# Total training time: 0.00 seconds.
# -- Epoch 89
# Norm: 9.83, NNZs: 1, Bias: 1.152771, T: 356, Avg. loss: 0.136876
# Total training time: 0.00 seconds.
# -- Epoch 90
# Norm: 9.82, NNZs: 1, Bias: 1.150414, T: 360, Avg. loss: 0.135388
# Total training time: 0.00 seconds.
# -- Epoch 91
# Norm: 9.82, NNZs: 1, Bias: 1.148421, T: 364, Avg. loss: 0.136156
# Total training time: 0.00 seconds.
# -- Epoch 92
# Norm: 9.83, NNZs: 1, Bias: 1.146666, T: 368, Avg. loss: 0.135145
# Total training time: 0.00 seconds.
# -- Epoch 93
# Norm: 9.83, NNZs: 1, Bias: 1.144556, T: 372, Avg. loss: 0.134852
# Total training time: 0.00 seconds.
# -- Epoch 94
# Norm: 9.82, NNZs: 1, Bias: 1.142245, T: 376, Avg. loss: 0.133413
# Total training time: 0.00 seconds.
# -- Epoch 95
# Norm: 9.83, NNZs: 1, Bias: 1.140286, T: 380, Avg. loss: 0.134147
# Total training time: 0.00 seconds.
# -- Epoch 96
# Norm: 9.83, NNZs: 1, Bias: 1.138559, T: 384, Avg. loss: 0.133170
# Total training time: 0.00 seconds.
# -- Epoch 97
# Norm: 9.83, NNZs: 1, Bias: 1.136488, T: 388, Avg. loss: 0.132883
# Total training time: 0.00 seconds.
# -- Epoch 98
# Norm: 9.83, NNZs: 1, Bias: 1.134220, T: 392, Avg. loss: 0.131490
# Total training time: 0.00 seconds.
# -- Epoch 99
# Norm: 9.83, NNZs: 1, Bias: 1.132294, T: 396, Avg. loss: 0.132192
# Total training time: 0.00 seconds.
# -- Epoch 100
# Norm: 9.83, NNZs: 1, Bias: 1.130595, T: 400, Avg. loss: 0.131247
# Total training time: 0.00 seconds.
# -- Epoch 101
# Norm: 9.83, NNZs: 1, Bias: 1.128561, T: 404, Avg. loss: 0.130966
# Total training time: 0.00 seconds.
# -- Epoch 102
# Norm: 9.83, NNZs: 1, Bias: 1.126334, T: 408, Avg. loss: 0.129616
# Total training time: 0.00 seconds.
# -- Epoch 103
# Norm: 9.83, NNZs: 1, Bias: 1.124440, T: 412, Avg. loss: 0.130289
# Total training time: 0.00 seconds.
# -- Epoch 104
# Norm: 9.83, NNZs: 1, Bias: 1.122767, T: 416, Avg. loss: 0.129374
# Total training time: 0.00 seconds.
# -- Epoch 105
# Norm: 9.83, NNZs: 1, Bias: 1.120768, T: 420, Avg. loss: 0.129098
# Total training time: 0.00 seconds.
# -- Epoch 106
# Norm: 9.83, NNZs: 1, Bias: 1.118581, T: 424, Avg. loss: 0.127789
# Total training time: 0.00 seconds.
# -- Epoch 107
# Norm: 9.83, NNZs: 1, Bias: 1.116717, T: 428, Avg. loss: 0.128434
# Total training time: 0.00 seconds.
# -- Epoch 108
# Norm: 9.83, NNZs: 1, Bias: 1.115069, T: 432, Avg. loss: 0.127547
# Total training time: 0.00 seconds.
# -- Epoch 109
# Norm: 9.83, NNZs: 1, Bias: 1.113104, T: 436, Avg. loss: 0.127277
# Total training time: 0.00 seconds.
# -- Epoch 110
# Norm: 9.83, NNZs: 1, Bias: 1.110955, T: 440, Avg. loss: 0.126007
# Total training time: 0.00 seconds.
# -- Epoch 111
# Norm: 9.83, NNZs: 1, Bias: 1.109120, T: 444, Avg. loss: 0.126626
# Total training time: 0.00 seconds.
# -- Epoch 112
# Norm: 9.83, NNZs: 1, Bias: 1.107496, T: 448, Avg. loss: 0.125765
# Total training time: 0.00 seconds.
# -- Epoch 113
# Norm: 9.83, NNZs: 1, Bias: 1.105563, T: 452, Avg. loss: 0.125500
# Total training time: 0.00 seconds.
# -- Epoch 114
# Norm: 9.83, NNZs: 1, Bias: 1.103450, T: 456, Avg. loss: 0.124266
# Total training time: 0.00 seconds.
# -- Epoch 115
# Norm: 9.83, NNZs: 1, Bias: 1.101643, T: 460, Avg. loss: 0.124862
# Total training time: 0.01 seconds.
# -- Epoch 116
# Norm: 9.83, NNZs: 1, Bias: 1.100042, T: 464, Avg. loss: 0.124026
# Total training time: 0.01 seconds.
# -- Epoch 117
# Norm: 9.83, NNZs: 1, Bias: 1.098140, T: 468, Avg. loss: 0.123766
# Total training time: 0.01 seconds.
# -- Epoch 118
# Norm: 9.83, NNZs: 1, Bias: 1.096062, T: 472, Avg. loss: 0.122567
# Total training time: 0.01 seconds.
# -- Epoch 119
# Norm: 9.83, NNZs: 1, Bias: 1.094282, T: 476, Avg. loss: 0.123140
# Total training time: 0.01 seconds.
# -- Epoch 120
# Norm: 9.83, NNZs: 1, Bias: 1.092704, T: 480, Avg. loss: 0.122328
# Total training time: 0.01 seconds.
# -- Epoch 121
# Norm: 9.83, NNZs: 1, Bias: 1.090831, T: 484, Avg. loss: 0.122072
# Total training time: 0.01 seconds.
# -- Epoch 122
# Norm: 9.83, NNZs: 1, Bias: 1.088786, T: 488, Avg. loss: 0.120906
# Total training time: 0.01 seconds.
# -- Epoch 123
# Norm: 9.83, NNZs: 1, Bias: 1.087032, T: 492, Avg. loss: 0.121458
# Total training time: 0.01 seconds.
# -- Epoch 124
# Norm: 9.84, NNZs: 1, Bias: 1.085476, T: 496, Avg. loss: 0.120668
# Total training time: 0.01 seconds.
# -- Epoch 125
# Norm: 9.84, NNZs: 1, Bias: 1.083632, T: 500, Avg. loss: 0.120417
# Total training time: 0.01 seconds.
# -- Epoch 126
# Norm: 9.83, NNZs: 1, Bias: 1.081619, T: 504, Avg. loss: 0.119283
# Total training time: 0.01 seconds.
# -- Epoch 127
# Norm: 9.83, NNZs: 1, Bias: 1.079890, T: 508, Avg. loss: 0.119815
# Total training time: 0.01 seconds.
# -- Epoch 128
# Norm: 9.84, NNZs: 1, Bias: 1.078355, T: 512, Avg. loss: 0.119046
# Total training time: 0.01 seconds.
# -- Epoch 129
# Norm: 9.84, NNZs: 1, Bias: 1.076538, T: 516, Avg. loss: 0.118799
# Total training time: 0.01 seconds.
# -- Epoch 130
# Norm: 9.84, NNZs: 1, Bias: 1.074556, T: 520, Avg. loss: 0.117695
# Total training time: 0.01 seconds.
# -- Epoch 131
# Norm: 9.84, NNZs: 1, Bias: 1.072852, T: 524, Avg. loss: 0.118208
# Total training time: 0.01 seconds.
# -- Epoch 132
# Norm: 9.84, NNZs: 1, Bias: 1.071336, T: 528, Avg. loss: 0.117459
# Total training time: 0.01 seconds.
# -- Epoch 133
# Norm: 9.84, NNZs: 1, Bias: 1.069546, T: 532, Avg. loss: 0.117217
# Total training time: 0.01 seconds.
# -- Epoch 134
# Norm: 9.84, NNZs: 1, Bias: 1.067594, T: 536, Avg. loss: 0.116141
# Total training time: 0.01 seconds.
# -- Epoch 135
# Norm: 9.84, NNZs: 1, Bias: 1.065913, T: 540, Avg. loss: 0.116636
# Total training time: 0.01 seconds.
# -- Epoch 136
# Norm: 9.84, NNZs: 1, Bias: 1.064417, T: 544, Avg. loss: 0.115907
# Total training time: 0.01 seconds.
# -- Epoch 137
# Norm: 9.84, NNZs: 1, Bias: 1.062653, T: 548, Avg. loss: 0.115669
# Total training time: 0.01 seconds.
# -- Epoch 138
# Norm: 9.84, NNZs: 1, Bias: 1.060729, T: 552, Avg. loss: 0.114621
# Total training time: 0.01 seconds.
# -- Epoch 139
# Norm: 9.84, NNZs: 1, Bias: 1.059071, T: 556, Avg. loss: 0.115099
# Total training time: 0.01 seconds.
# -- Epoch 140
# Norm: 9.84, NNZs: 1, Bias: 1.057594, T: 560, Avg. loss: 0.114388
# Total training time: 0.01 seconds.
# -- Epoch 141
# Norm: 9.84, NNZs: 1, Bias: 1.055855, T: 564, Avg. loss: 0.114154
# Total training time: 0.01 seconds.
# -- Epoch 142
# Norm: 9.84, NNZs: 1, Bias: 1.053958, T: 568, Avg. loss: 0.113132
# Total training time: 0.01 seconds.
# -- Epoch 143
# Norm: 9.84, NNZs: 1, Bias: 1.052322, T: 572, Avg. loss: 0.113594
# Total training time: 0.01 seconds.
# -- Epoch 144
# Norm: 9.84, NNZs: 1, Bias: 1.050864, T: 576, Avg. loss: 0.112901
# Total training time: 0.01 seconds.
# -- Epoch 145
# Norm: 9.84, NNZs: 1, Bias: 1.049148, T: 580, Avg. loss: 0.112671
# Total training time: 0.01 seconds.
# -- Epoch 146
# Norm: 9.84, NNZs: 1, Bias: 1.047279, T: 584, Avg. loss: 0.111674
# Total training time: 0.01 seconds.
# -- Epoch 147
# Norm: 9.84, NNZs: 1, Bias: 1.045664, T: 588, Avg. loss: 0.112120
# Total training time: 0.01 seconds.
# Convergence after 147 epochs took 0.01 seconds
# SGDRegressor(max_iter=5000, verbose=1)

# %%
sgd.score(data[["시간"]],data["성적"])
# Out:
# 0.9996807485752534

# %%
sgd.predict([[7]])
# Out:
# array([69.92622825])

# %% [markdown]
# #### 보스턴 집값 데이터를 이용한 회귀 분석

# %%
from sklearn.datasets import load_boston

boston = load_boston()

boston.keys()
# data : 특성 데이터
# target : 라벨데이터
# feature_names : 컬럼의 이름
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
data_df = pd.DataFrame(boston.data, columns=boston.feature_names)
data_df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
target_df=pd.DataFrame(boston.target, columns=["price"])
target_df
# Out:
#      price
# 0     24.0
# 1     21.6
# 2     34.7
# 3     33.4
# 4     36.2
# ..     ...
# 501   22.4
# 502   20.6
# 503   23.9
# 504   22.0
# 505   11.9
#
# [506 rows x 1 columns]

# %%
# axis=1 가로방향으로 병합
boston_df = pd.concat([data_df,target_df],axis=1)
boston_df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  price
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# 2       17.8  392.83   4.03   34.7
# 3       18.7  394.63   2.94   33.4
# 4       18.7  396.90   5.33   36.2
# ..       ...     ...    ...    ...
# 501     21.0  391.99   9.67   22.4
# 502     21.0  396.90   9.08   20.6
# 503     21.0  396.90   5.64   23.9
# 504     21.0  393.45   6.48   22.0
# 505     21.0  396.90   7.88   11.9
#
# [506 rows x 14 columns]

# %%
import seaborn as sb

plt.figure(figsize=(10,10))
sb.heatmap(boston_df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
# 훈련데이터와 테스트 데이터로 분리
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data_df,target_df,random_state=777)

# %%
linear = LinearRegression()

linear.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 회귀분석의 평가는 오차를 이용하므로 mse를 사용
from sklearn.metrics import mean_squared_error

pred_train = linear.predict(X_train)
pred_test = linear.predict(X_test)
print(mean_squared_error(pred_train, y_train))
print(mean_squared_error(pred_test, y_test))
# Out:
# 21.851070078329464
# 22.971490334406354

# %% [markdown]
# #### 규제를 사용한 과대적합 감소
#
# - Ridge : 특성수가 적은 경우에 상관관계가 큰 컬럼과 작은 컬럼의 차이를 줄여서 작은 컬럼도 사용하는 것
# - Lasso : 특성수가 많은 경우에 상관관계가 적은 컬럼을 제거 -> 특성 선택에 사용

# %%
from sklearn.linear_model import Ridge, Lasso

# alpha =0.1: 규제값
ridge= Ridge(alpha=0.1)
lasso = Lasso(alpha=0.1)

ridge.fit(X_train,y_train)
lasso.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.1)

# %%
ridge_pred_train=ridge.predict(X_train)
ridge_pred_test=ridge.predict(X_test)

print(mean_squared_error(ridge_pred_train,y_train))
print(mean_squared_error(ridge_pred_test,y_test))
# Out:
# 21.862183071097885
# 22.706503966790766

# %%
lasso_pred_train=lasso.predict(X_train)
lasso_pred_test=lasso.predict(X_test)

print(mean_squared_error(lasso_pred_train,y_train))
print(mean_squared_error(lasso_pred_test,y_test))
# Out:
# 23.351722349297923
# 22.22541006280776

# %% [markdown]
# ### Logistic Regression
# - 비선형 이진 분류 모델

# %%
import pandas as pd

# %%
wine = pd.read_csv("./data/wine.csv")
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  type
# 0      9.4        5     1
# 1      9.8        5     1
# 2      9.8        5     1
# 3      9.8        6     1
# 4      9.4        5     1

# %%
X = wine.iloc[:,:-1]
y = wine.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test=train_test_split(X,y,random_state=999)

# %%
from sklearn.linear_model import LogisticRegression

# C : 작을수록 규제를 강하게 함(사용되는 특성이나 데이터 수를 줄여주는 것)
lr = LogisticRegression(C=0.01,max_iter=15000)
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(C=0.01, max_iter=15000)

# %%
print("훈련 : ",lr.score(X_train,y_train))
print("테스트 : ",lr.score(X_test,y_test))
# Out:
# 훈련 :  0.9493021346469622
# 테스트 :  0.9452307692307692

# %%
from sklearn.model_selection import GridSearchCV
# GridSearch로 최적의 C 값을 찾아보자
param={"C":[0.001,0.01,0.1,1,10,100,1000]}

gs = GridSearchCV(LogisticRegression(max_iter=15000,random_state=777),param, cv=10)
gs.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=LogisticRegression(max_iter=15000, random_state=777),
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000]})

# %%
print("훈련 : ",gs.score(X_train,y_train))
print("테스트 : ",gs.score(X_test,y_test))
# Out:
# 훈련 :  0.9891215106732348
# 테스트 :  0.9876923076923076

# %%
gs.best_params_
# Out:
# {'C': 100}
